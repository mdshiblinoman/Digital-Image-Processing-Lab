# %%
import cv2
import matplotlib.pyplot as plt

# Read Image
image = cv2.imread("cat.png")

# Convert image to grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Gray-Level Slicing Parameters
low = 100
high = 200

# 1. Gray-Level Slicing WITHOUT Background
# Pixels within the range become white (255)
# Other pixels become black (0)
without_background = cv2.inRange(gray, low, high)


# 2. Gray-Level Slicing WITH Background
# Copy original grayscale image
with_background = gray.copy()

# Pixels within the range become white
with_background[
    (gray >= low) & (gray <= high)
] = 255

# Display Results
plt.figure(figsize=(12, 8))

# Original Image
plt.subplot(2, 2, 1)
plt.imshow(gray, cmap="gray")
plt.title("Original Grayscale Image")
plt.axis("off")

# Without Background
plt.subplot(2, 2, 2)
plt.imshow(without_background, cmap="gray")
plt.title("Gray-Level Slicing Without Background")
plt.axis("off")

# With Background
plt.subplot(2, 2, 3)
plt.imshow(with_background, cmap="gray")
plt.title("Gray-Level Slicing With Background")
plt.axis("off")

plt.tight_layout()
plt.show()
